# %% [markdown]
# # Hugging Face as a Data and ML Model Hub
# ---
#
# **Learning goal**
#
#
# In this notebook, we will build a tiny ML prediction project without training a model from scratch, but with using pretrained models on Hugging Face.
#
# ---
